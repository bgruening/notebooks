# %% [markdown]
# # This notebook will build a Galaxy tool_dependencies.xml file for a Python Package
#
# Simply replace the package name in cell 1. Please note that it does not currently do recursive dependency finding.

# %%
# !python python_module_generator.py Pillow
# Out:
# <?xml version="1.0"?>
# <tool_dependency>
#     <package name="python" version="2.7">
#         <repository name="package_python_2_7" owner="iuc" prior_installation_required="True" />
#     </package>
#     <package name="Pillow" version="2.7.0">
#         <install version="1.0">
#             <actions>
#                 <action type="setup_python_environment">
#                     <repository name="package_python_2_7" owner="iuc">
#                         <package name="python" version="2.7" />
#                     </repository>
#                     <!-- allow downloading and installing an Python package from https://pypi.org/ -->
#                     <package>https://pypi.python.org/packages/source/P/Pillow/Pillow-2.7.0.tar.gz#md5=3fdc9f16a1b60366ae8158b424655d10</package>
#                 </action>
#             </actions>
#         </install>
#         <readme><![CDATA[
# Pillow
# ...
#
# *Python Imaging Library (Fork)*
#
# ...

# %%
# !python python_module_generator.py Pillow --version 1.7.8
# Out:
# <?xml version="1.0"?>
# <tool_dependency>
#     <package name="python" version="2.7">
#         <repository name="package_python_2_7" owner="iuc" prior_installation_required="True" />
#     </package>
#     <package name="Pillow" version="1.7.8">
#         <install version="1.0">
#             <actions>
#                 <action type="setup_python_environment">
#                     <repository name="package_python_2_7" owner="iuc">
#                         <package name="python" version="2.7" />
#                     </repository>
#                     <!-- allow downloading and installing an Python package from https://pypi.org/ -->
#                     <package>https://pypi.python.org/packages/source/P/Pillow/Pillow-1.7.8.zip#md5=41d8688d4db72673069a6dc63b5289d6</package>
#                 </action>
#             </actions>
#         </install>
#         <readme><![CDATA[
# .. contents::
#
# Pillow
# ...
#
# ...
